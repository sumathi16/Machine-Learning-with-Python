# %%
import pandas as pd
data = pd.read_csv('data/Student Data ML Jan.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
# Timestamp        26 non-null object
# Name             26 non-null object
# MailId           26 non-null object
# Branch           26 non-null object
# Qualification    26 non-null object
# RollNumber       26 non-null object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
data.Branch
# Out:
# 0                         IT
# 1                        MCA
# 2                        MCA
# 3                        MCA
# 4                        cse
# 5                        CSE
# 6                        CSE
# 7     Information Technology
# 8               Data Science
# 9                        MCA
# 10               DataScience
# 11          Computer Science
# 12                        IT
# 13    Information Technology
# 14              Data Science
# 15                       ECE
# 16    Information Technology
# 17    Information Technology
# 18          b com(computers)
# 19                B.Sc(comp)
# 20          Computer Science
# 21              Data Science
# 22                       I.T
# 23         civil engineering
# 24                       I.T
# 25    Automobile Engineering
# Name: Branch, dtype: object

# %% [markdown]
# ##### Fancy Indexing

# %%
data.Qualification #data[0:]
# Out:
# 0     B.Tech
# 1         PG
# 2         PG
# 3         PG
# 4      BTech
# 5     B.Tech
# 6     B.Tech
# 7     B.Tech
# 8       M.sc
# 9         PG
# 10       Msc
# 11       MCA
# 12    B.Tech
# 13    B.TECH
# 14       MSc
# 15    B.Tech
# 16    B.Tech
# 17    B.tech
# 18    degree
# 19    Degree
# 20       MCA
# 21      M.Sc
# 22    B.TECH
# 23    B-tech
# 24    B.TECH
# 25       B.E
# Name: Qualification, dtype: object

# %%
data.loc[0:,"Qualification"]
# Out:
# 0     B.Tech
# 1         PG
# 2         PG
# 3         PG
# 4      BTech
# 5     B.Tech
# 6     B.Tech
# 7     B.Tech
# 8       M.sc
# 9         PG
# 10       Msc
# 11       MCA
# 12    B.Tech
# 13    B.TECH
# 14       MSc
# 15    B.Tech
# 16    B.Tech
# 17    B.tech
# 18    degree
# 19    Degree
# 20       MCA
# 21      M.Sc
# 22    B.TECH
# 23    B-tech
# 24    B.TECH
# 25       B.E
# Name: Qualification, dtype: object

# %%
data['Qualification']
# Out:
# 0     B.Tech
# 1         PG
# 2         PG
# 3         PG
# 4      BTech
# 5     B.Tech
# 6     B.Tech
# 7     B.Tech
# 8       M.sc
# 9         PG
# 10       Msc
# 11       MCA
# 12    B.Tech
# 13    B.TECH
# 14       MSc
# 15    B.Tech
# 16    B.Tech
# 17    B.tech
# 18    degree
# 19    Degree
# 20       MCA
# 21      M.Sc
# 22    B.TECH
# 23    B-tech
# 24    B.TECH
# 25       B.E
# Name: Qualification, dtype: object

# %%
data.Qualification=='PG'
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# Name: Qualification, dtype: bool

# %%
# Get the PG students data
data[data.Qualification=='PG']
# Out:
#              Timestamp               Name                          MailId  \
# 1  30/01/2020 15:00:20           R deepak          deepakrella9@gmail.com
# 2  30/01/2020 15:00:23      P K CHAITANYA            chaitu1495@gmail.com
# 3  30/01/2020 15:00:25         B SRIKANTH         srikanthbisai@gmail.com
# 9  30/01/2020 15:00:41  k.parameswara rao  parameshkarumuri1997@gmail.com
#
#   Branch Qualification    RollNumber
# 1    MCA            PG  121722501019
# 2    MCA            PG  121722501015
# 3    MCA            PG  121722501002
# 9    MCA            PG  121722501011

# %%
data[data.Qualification=='B.TECH']
# Out:
#               Timestamp                       Name  \
# 13  30/01/2020 15:01:10               Harish Bandi
# 22  30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 24  30/01/2020 15:04:10            SAI TEJA JALADI
#
#                          MailId                  Branch Qualification  \
# 13      harishbandi12@gmail.com  Information Technology        B.TECH
# 22  duppatijayanaveen@gmail.com                     I.T        B.TECH
# 24  saitejajaladi2000@gmail.com                     I.T        B.TECH
#
#     RollNumber
# 13  161FA07035
# 22  161FA07012
# 24  161FA07025

# %%
# Get the B.TECH student Mail IDs
data['MailId'][data.Qualification=='B.TECH']
# Out:
# 13        harishbandi12@gmail.com
# 22    duppatijayanaveen@gmail.com
# 24    saitejajaladi2000@gmail.com
# Name: MailId, dtype: object

# %%
# Student RollNumbers with Branch Data Science
data['RollNumber'][data.Branch == 'Data Science']
# Out:
# 8     121822502015
# 14    121822502018
# 21    121822502016
# Name: RollNumber, dtype: object

# %%
data['RollNumber'][data.Branch == 'IT']
# Out:
# 0     161FA07039
# 12    161FA07050
# Name: RollNumber, dtype: object

# %%
data.Branch
# Out:
# 0                         IT
# 1                        MCA
# 2                        MCA
# 3                        MCA
# 4                        cse
# 5                        CSE
# 6                        CSE
# 7     Information Technology
# 8               Data Science
# 9                        MCA
# 10               DataScience
# 11          Computer Science
# 12                        IT
# 13    Information Technology
# 14              Data Science
# 15                       ECE
# 16    Information Technology
# 17    Information Technology
# 18          b com(computers)
# 19                B.Sc(comp)
# 20          Computer Science
# 21              Data Science
# 22                       I.T
# 23         civil engineering
# 24                       I.T
# 25    Automobile Engineering
# Name: Branch, dtype: object

# %%
((data.Branch == 'IT') | (data.Branch == 'I.T')).sum()
# Out:
# 4

# %%
((data.Branch == 'IT') | (data.Branch == 'I.T') |\
          (data.Branch == 'Information Technology')   ).sum()
# Out:
# 8

# %%
(data.Branch == 'IT') or (data.Branch == 'I.T')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-41fb9963b635> in <module>
# ----> 1 (data.Branch == 'IT') or (data.Branch == 'I.T')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
(data.Branch == 'IT').any()
# Out:
# True

# %%
(data.Branch == 'IT').all()
# Out:
# False

# %%
True or False
# Out:
# True

# %%
[True,False] or [ False,True]
# Out:
# [True, False]

# %%
print(0 or 56)
print(56 or False)
print(6==7 or 8==8)
print(4+5 or 7+9)
print(5-5 or 6-2)
print(False or False)
print(False or 4-4)
# Out:
# 56
# 56
# True
# 9
# 4
# False
# 0

# %%
data.Qualification.value_counts()
# Out:
# B.Tech    7
# PG        4
# B.TECH    3
# MCA       2
# M.Sc      1
# B-tech    1
# Degree    1
# degree    1
# Msc       1
# B.E       1
# M.sc      1
# BTech     1
# MSc       1
# B.tech    1
# Name: Qualification, dtype: int64

# %%
data.Qualification[data.Qualification=='B.tech'] = 'B.Tech'
# Out:
# 17    B.tech
# Name: Qualification, dtype: object

# %%
# B.Tech,PG,MCA,MSc,B.E,Degree
#BTECH,PG,MCA,MSC,BE,DEGREE
data.Qualification[(data.Qualification=='B.tech') | (data.Qualification=='BTech')] = 'B.Tech'

# %%
data.Qualification.value_counts()
# Out:
# B.Tech    10
# PG         4
# B.TECH     3
# MCA        2
# M.Sc       1
# B.E        1
# degree     1
# M.sc       1
# Degree     1
# MSc        1
# Msc        1
# Name: Qualification, dtype: int64

# %% [markdown]
# Making a column as Index

# %%
data.set_index('RollNumber')
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 121722501019  30/01/2020 15:00:20                   R deepak
# 121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121722501011  30/01/2020 15:00:41          k.parameswara rao
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# ...

# %%
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
#data = data.set_index('RollNumber')
data.set_index('RollNumber',inplace=True)

# %%
data
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 121722501019  30/01/2020 15:00:20                   R deepak
# 121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121722501011  30/01/2020 15:00:41          k.parameswara rao
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# ...

# %% [markdown]
# Sorting the DataFrame

# %%
data.sort_values('Name')
# Out:
#                         Timestamp                       Name  \
# RollNumber
# y167189053    30/01/2020 15:01:50             Ananda Lakshmi
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 14F41A0461    30/01/2020 15:01:24             Devendra Kumar
# 121822502016  30/01/2020 15:02:41           G. Vineeth Kumar
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# 161FA07012    30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 140082202030  30/01/2020 15:01:56                K . krishna
# 121822502018  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# ...

# %%
data.sort_index()
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 121722501011  30/01/2020 15:00:41          k.parameswara rao
# 121722501013  30/01/2020 15:02:04       Md.Ali Asghar Khoyee
# 121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 121722501019  30/01/2020 15:00:20                   R deepak
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121822502016  30/01/2020 15:02:41           G. Vineeth Kumar
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 121822502018  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 133J1A0150    30/01/2020 15:02:59                   vikram S
# 140082202030  30/01/2020 15:01:56                K . krishna
# 14F41A0461    30/01/2020 15:01:24             Devendra Kumar
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# ...

# %%
data.sort_values('Branch')
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 245112769310  30/01/2020 15:07:38         SAIKUMAR MANIKONDA
# 140082202030  30/01/2020 15:01:56                K . krishna
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 121722501013  30/01/2020 15:02:04       Md.Ali Asghar Khoyee
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 121822502016  30/01/2020 15:02:41           G. Vineeth Kumar
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121822502018  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 14F41A0461    30/01/2020 15:01:24             Devendra Kumar
# 161FA07012    30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 161FA07025    30/01/2020 15:04:10            SAI TEJA JALADI
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# ...

# %%
data.sort_values('Qualification')
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 245112769310  30/01/2020 15:07:38         SAIKUMAR MANIKONDA
# 161FA07012    30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# 161FA07025    30/01/2020 15:04:10            SAI TEJA JALADI
# 133J1A0150    30/01/2020 15:02:59                   vikram S
# 161FA07049    30/01/2020 15:01:49            T.V.Naga Jyothi
# 161FA07002    30/01/2020 15:01:35                    M.Ramya
# 14F41A0461    30/01/2020 15:01:24             Devendra Kumar
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# ...

# %% [markdown]
# Merging the DataFrames

# %%
college = pd.read_csv('data/college.csv')
college
# Out:
#      RollNumber            College  Year
# 0  245112769310  MVSR Engg College  2016
# 1    161FA07025             Vignan  2020
# 2    161FA07002             Vignan  2020
# 3    133J1A0150              Raghu  2017
# 4    118W1A0416             Vignan  2015

# %%
data
# Out:
#       RollNumber            Timestamp                       Name  \
# 0     161FA07039  30/01/2020 15:00:07              Sai Naga Raju
# 1   121722501019  30/01/2020 15:00:20                   R deepak
# 2   121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 3   121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 4     161fa04079  30/01/2020 15:00:28           Himaja cherukuri
# 5     161FA04180  30/01/2020 15:00:28              M.Geethanjali
# 6     161FA04106  30/01/2020 15:00:33                  M.Nikhita
# 7     161FA07042  30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 9   121722501011  30/01/2020 15:00:41          k.parameswara rao
# 10  121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 11  121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12    161FA07050  30/01/2020 15:00:45      Thatavarti kavya sree
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#     index    RollNumber            Timestamp                       Name  \
# 0       0    161FA07039  30/01/2020 15:00:07              Sai Naga Raju
# 1       1  121722501019  30/01/2020 15:00:20                   R deepak
# 2       2  121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 3       3  121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 4       4    161fa04079  30/01/2020 15:00:28           Himaja cherukuri
# 5       5    161FA04180  30/01/2020 15:00:28              M.Geethanjali
# 6       6    161FA04106  30/01/2020 15:00:33                  M.Nikhita
# 7       7    161FA07042  30/01/2020 15:00:37           DASARI PAVAN SAI
# 8       8  121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 9       9  121722501011  30/01/2020 15:00:41          k.parameswara rao
# 10     10  121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 11     11  121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# ...

# %%
pd.merge(data,college,how='inner')
# Out:
#    index    RollNumber            Timestamp                Name  \
# 0     16    161FA07002  30/01/2020 15:01:35             M.Ramya
# 1     23    133J1A0150  30/01/2020 15:02:59            vikram S
# 2     24    161FA07025  30/01/2020 15:04:10     SAI TEJA JALADI
# 3     25  245112769310  30/01/2020 15:07:38  SAIKUMAR MANIKONDA
#
#                           MailId                  Branch Qualification  \
# 0     ramya.marripoodi@gmail.com  Information Technology        B.Tech
# 1  vikramsabbavarapu60@gmail.com       civil engineering        B.Tech
# 2    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 3          saikumarm64@gmail.com  Automobile Engineering           B.E
#
#              College  Year
# 0             Vignan  2020
# 1              Raghu  2017
# 2             Vignan  2020
# 3  MVSR Engg College  2016

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
pd.merge(data,college,how='left')
# Out:
#     index    RollNumber            Timestamp                       Name  \
# 0       0    161FA07039  30/01/2020 15:00:07              Sai Naga Raju
# 1       1  121722501019  30/01/2020 15:00:20                   R deepak
# 2       2  121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 3       3  121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 4       4    161fa04079  30/01/2020 15:00:28           Himaja cherukuri
# 5       5    161FA04180  30/01/2020 15:00:28              M.Geethanjali
# 6       6    161FA04106  30/01/2020 15:00:33                  M.Nikhita
# 7       7    161FA07042  30/01/2020 15:00:37           DASARI PAVAN SAI
# 8       8  121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 9       9  121722501011  30/01/2020 15:00:41          k.parameswara rao
# 10     10  121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 11     11  121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# ...

# %%
pd.merge(data,college,how='right')
# Out:
#    index    RollNumber            Timestamp                Name  \
# 0   16.0    161FA07002  30/01/2020 15:01:35             M.Ramya
# 1   23.0    133J1A0150  30/01/2020 15:02:59            vikram S
# 2   24.0    161FA07025  30/01/2020 15:04:10     SAI TEJA JALADI
# 3   25.0  245112769310  30/01/2020 15:07:38  SAIKUMAR MANIKONDA
# 4    NaN    118W1A0416                  NaN                 NaN
#
#                           MailId                  Branch Qualification  \
# 0     ramya.marripoodi@gmail.com  Information Technology        B.Tech
# 1  vikramsabbavarapu60@gmail.com       civil engineering        B.Tech
# 2    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 3          saikumarm64@gmail.com  Automobile Engineering           B.E
# 4                            NaN                     NaN           NaN
#
#              College  Year
# 0             Vignan  2020
# 1              Raghu  2017
# 2             Vignan  2020
# 3  MVSR Engg College  2016
# ...

# %%
pd.merge(data,college,how='outer')
# Out:
#     index    RollNumber            Timestamp                       Name  \
# 0     0.0    161FA07039  30/01/2020 15:00:07              Sai Naga Raju
# 1     1.0  121722501019  30/01/2020 15:00:20                   R deepak
# 2     2.0  121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 3     3.0  121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 4     4.0    161fa04079  30/01/2020 15:00:28           Himaja cherukuri
# 5     5.0    161FA04180  30/01/2020 15:00:28              M.Geethanjali
# 6     6.0    161FA04106  30/01/2020 15:00:33                  M.Nikhita
# 7     7.0    161FA07042  30/01/2020 15:00:37           DASARI PAVAN SAI
# 8     8.0  121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 9     9.0  121722501011  30/01/2020 15:00:41          k.parameswara rao
# 10   10.0  121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 11   11.0  121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# ...

# %%
data.shape[0],college.shape[0]
# Out:
# (26, 5)

# %% [markdown]
# data,college
# - inner - Students availble in both datafrmaes(intersection) -->4 rows
# - outer - student who are there in atleast one dataframe(union)-->27
# - left - Roll numbers avialble in Data -->26
# - right - Roll numbers availble in college -->5

# %% [markdown]
# Task <br>
# Different column names in two dataframes<br>
# college - 'Roll Number'<br>
# data - 'Roll Number'

# %%
college = pd.read_csv('data/college.csv')
college.columns
# Out:
# Index(['Roll Number', 'College', 'Year'], dtype='object')

# %%
data.columns
# Out:
# Index(['index', 'RollNumber', 'Timestamp', 'Name', 'MailId', 'Branch',
#        'Qualification'],
#       dtype='object')

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
common_data = pd.merge(data,college,left_on='RollNumber',right_on='Roll Number')
common_data
# Out:
#    index    RollNumber            Timestamp                Name  \
# 0     16    161FA07002  30/01/2020 15:01:35             M.Ramya
# 1     23    133J1A0150  30/01/2020 15:02:59            vikram S
# 2     24    161FA07025  30/01/2020 15:04:10     SAI TEJA JALADI
# 3     25  245112769310  30/01/2020 15:07:38  SAIKUMAR MANIKONDA
#
#                           MailId                  Branch Qualification  \
# 0     ramya.marripoodi@gmail.com  Information Technology        B.Tech
# 1  vikramsabbavarapu60@gmail.com       civil engineering        B.Tech
# 2    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 3          saikumarm64@gmail.com  Automobile Engineering           B.E
#
#     Roll Number            College  Year
# 0    161FA07002             Vignan  2020
# 1    133J1A0150              Raghu  2017
# 2    161FA07025             Vignan  2020
# 3  245112769310  MVSR Engg College  2016

# %%
common_data.drop('Roll Number',axis=1,inplace=True)

# %%
common_data
# Out:
#    index    RollNumber            Timestamp                Name  \
# 0     16    161FA07002  30/01/2020 15:01:35             M.Ramya
# 1     23    133J1A0150  30/01/2020 15:02:59            vikram S
# 2     24    161FA07025  30/01/2020 15:04:10     SAI TEJA JALADI
# 3     25  245112769310  30/01/2020 15:07:38  SAIKUMAR MANIKONDA
#
#                           MailId                  Branch Qualification  \
# 0     ramya.marripoodi@gmail.com  Information Technology        B.Tech
# 1  vikramsabbavarapu60@gmail.com       civil engineering        B.Tech
# 2    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 3          saikumarm64@gmail.com  Automobile Engineering           B.E
#
#              College  Year
# 0             Vignan  2020
# 1              Raghu  2017
# 2             Vignan  2020
# 3  MVSR Engg College  2016
